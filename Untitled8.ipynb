# %% [markdown]
# <a href="https://colab.research.google.com/github/dataandai/Domainspecific-pretrain-for-BERT/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import numpy as np

class AdamOptim():
    def __init__(self, eta=0.1, beta1=0.9, beta2=0.999, epsilon=1e-8):
        self.m_dw, self.v_dw = 0, 0
        self.m_db, self.v_db = 0, 0
        self.beta1 = beta1
        self.beta2 = beta2
        self.epsilon = epsilon
        self.eta = eta
    def updates(self, t, weight, b, dw, db):
        ## dw, db are from current minibatch
        #weights 
        self.m_dw = self.beta1*self.m_dw + (1-self.beta1)*dw
        self.m_db = self.beta1*self.m_db + (1-self.beta1)*db

        ## rms beta 2
        self.v_dw = self.beta2*self.v_dw + (1-self.beta2)*(dw**2)

        self.v_db = self.beta2*self.v_db + (1-self.beta2)*(db)

    
        m_dw_corr = self.m_dw/(1-self.beta1**t)
        m_db_corr = self.m_db/(1-self.beta1**t)
        v_dw_corr = self.v_dw/(1-self.beta2**t)
        v_db_corr = self.v_db/(1-self.beta2**t)

    
        weight = weight - self.eta*(m_dw_corr/(np.sqrt(v_dw_corr)+self.epsilon))
        b = b - self.eta*(m_db_corr/(np.sqrt(v_db_corr)+self.epsilon))
        return weight, b
def lossfunction(m):
    
    return nn.CrossEntropyLoss(m)
#return m**2-2*m+1
## take derivative

def gradfunction(m):
    return 2*m-2
def checkconvergence(w0, w1):
    return (w0 == w1)
w_0 = 0
b0 = 0
adam = AdamOptim()
t = 1 
converged = False

while not converged:
    dw = gradfunction(w_0)
    db = gradfunction(b0)
    w_0_old = w_0
    w_0, b0 = adam.updates(t,weight=w_0, b=b0, dw=dw, db=db)
    if checkconvergence(w_0, w_0_old):
        print('converged after '+str(t)+' iterations')
        break
    else:
        print('iteration '+str(t)+': weight='+str(w_0))
        t+=1
# Out:
# iteration 1: weight=0.0999999995
# iteration 2: weight=0.19958777130820715
# iteration 3: weight=0.29841372705396974
# iteration 4: weight=0.3960609394262539
# iteration 5: weight=0.49203634073565794
# iteration 6: weight=0.585763544006338
# iteration 7: weight=0.6765792950608979
# iteration 8: weight=0.7637362754789581
# iteration 9: weight=0.8464154399296363
# iteration 10: weight=0.9237508443930877
# iteration 11: weight=0.9948684980519428
# iteration 12: weight=1.0589378906300473
# iteration 13: weight=1.1152309351411656
# iteration 14: weight=1.1631794751352849
# iteration 15: weight=1.2024210893915044
# iteration 16: weight=1.2328249102424955
# iteration 17: weight=1.2544940872815118
# iteration 18: weight=1.2677472823696139
# iteration 19: weight=1.2730857716970154
# iteration 20: weight=1.2711540954901284
# iteration 21: weight=1.26270104107937
# iteration 22: weight=1.248545290077988
# iteration 23: weight=1.2295475224497154
# iteration 24: weight=1.20658885546974
# ...
